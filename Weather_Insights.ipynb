# %% [markdown]
# WEATHER DATA INSIGHTS

# %%
#Importing tools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
#Data Extraction/Collection
csv_file_path = r'C:\DS\LUX\1. Weather Data.csv'
df = pd.read_csv(csv_file_path)

# %%
#Top 10 Rows
df.head(10)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
# 5  1/1/2012 5:00    -1.4              -3.3         87                9
# 6  1/1/2012 6:00    -1.5              -3.1         89                7
# 7  1/1/2012 7:00    -1.4              -3.6         85                7
# 8  1/1/2012 8:00    -1.4              -3.6         85                9
# 9  1/1/2012 9:00    -1.3              -3.1         88               15
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# ...

# %%
# Bottom 10 rows
df.tail(10)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8774  12/31/2012 14:00    -3.4              -5.7         84                6
# 8775  12/31/2012 15:00    -2.3              -4.6         84                9
# 8776  12/31/2012 16:00    -1.4              -4.0         82               13
# 8777  12/31/2012 17:00    -1.1              -3.3         85               19
# 8778  12/31/2012 18:00    -1.3              -3.1         88               17
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8774           11.3     100.57    Snow
# 8775            9.7     100.47    Snow
# ...

# %%
# Total Number of Rows and Columns
df.shape
# Out:
# (8784, 8)

# %%
# Total Number of Columns
df.shape[1]
# Out:
# 8

# %%
# Total Number of Columns
len(df.columns)
# Out:
# 8

# %%
# Total Number of Rows
df.shape[0]
# Out:
# 8784

# %%
#Total Number of Rows
len(df.index)
# Out:
# 8784

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
# Data Description
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
#  Weather Records with Exactly clear
clear_weather = df[df['Weather'] == 'Clear']
print(clear_weather)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
# Number of times the wind speed was exactly 4 km/hr
wind_speed_4_kmh = df[df['Wind Speed_km/h'] == 4]
#print(wind_speed_4_kmh)
count = wind_speed_4_kmh.shape[0]
print(f"The wind speed was 4 km/hr {count} times.")
# Out:
# The wind speed was 4 km/hr 474 times.

# %%
# Finding Null Values
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
# Column Rename
df.rename(columns={'Weather':'Weather_Condition'})
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
# Mean Visibility
print(df['Visibility_km' ].mean())
# Out:
# 27.664446721311478

# %%
# Number of records where the wind speed is greater than 24 km/hr and visibility is equal to 25 km.
records = df[(df['Wind Speed_km/h'] > 24) & (df['Visibility_km'] == 25)]
count = records.shape[0]
print(f"The number of records where the wind speed is greater than 24 km/hr and visibility is equal to 25 km is {count}.")
# Out:
# The number of records where the wind speed is greater than 24 km/hr and visibility is equal to 25 km is 308.

# %%
# Instances where the weather is clear and the relative humidity is greater than 50, or visibility is above 40.
filtered_clear = df[(df['Weather'] == 'Clear') & ((df['Rel Hum_%'] > 50) | (df['Visibility_km'] > 40))]
print(filtered_clear)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# 241     1/11/2012 1:00   -10.7             -17.8         56               17
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
#Number of weather conditions that include snow.
snow_conditions = df['Weather'].str.contains('snow', case=False, na=False).sum()
print(f"The number of weather conditions that include 'snow' is: {snow_conditions}")
# Out:
# The number of weather conditions that include 'snow' is: 583

# %% [markdown]
# EDA

# %%
df.info()
#This dataset has a total number of 8784 records
#There are 8 columns in total
# The data types available in the records are floats,intergers and objects
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
df['Date/Time'] = pd.to_datetime(df['Date/Time'],infer_datetime_format=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17772\2085478035.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['Date/Time'] = pd.to_datetime(df['Date/Time'],infer_datetime_format=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   datetime64[ns]
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 549.1+ KB

# %%
df.isnull().sum()
#The dataset has no missing values
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
df.duplicated().sum()
#There are no dulpicate records
# Out:
# 0

# %%
df.value_counts('Weather')
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
df.describe()
# Out:
#                  Date/Time       Temp_C  Dew Point Temp_C    Rel Hum_%  \
# count                 8784  8784.000000       8784.000000  8784.000000
# mean   2012-07-01 23:30:00     8.798144          2.555294    67.431694
# min    2012-01-01 00:00:00   -23.300000        -28.500000    18.000000
# 25%    2012-04-01 11:45:00     0.100000         -5.900000    56.000000
# 50%    2012-07-01 23:30:00     9.300000          3.300000    68.000000
# 75%    2012-10-01 11:15:00    18.800000         11.800000    81.000000
# max    2012-12-31 23:00:00    33.000000         24.400000   100.000000
# std                    NaN    11.687883         10.883072    16.918881
#
#        Wind Speed_km/h  Visibility_km    Press_kPa
# count      8784.000000    8784.000000  8784.000000
# mean         14.945469      27.664447   101.051623
# min           0.000000       0.200000    97.520000
# 25%           9.000000      24.100000   100.560000
# 50%          13.000000      25.000000   101.070000
# ...

# %%
mode_values = df.mode(numeric_only=True)
mode_values
# Out:
#    Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  \
# 0    16.6              -0.9       68.0              9.0           25.0
# 1     NaN              12.9        NaN              NaN            NaN
#
#    Press_kPa
# 0     101.13
# 1        NaN

# %%
weather_mode = df['Weather'].mode()
weather_mode
# Out:
# 0    Mainly Clear
# Name: Weather, dtype: object

# %%
# View unique weather conditions
unique_weather_conditions = df['Weather'].unique()
print(unique_weather_conditions)
# Out:
# ['Fog' 'Freezing Drizzle,Fog' 'Mostly Cloudy' 'Cloudy' 'Rain'
#  'Rain Showers' 'Mainly Clear' 'Snow Showers' 'Snow' 'Clear'
#  'Freezing Rain,Fog' 'Freezing Rain' 'Freezing Drizzle' 'Rain,Snow'
#  'Moderate Snow' 'Freezing Drizzle,Snow' 'Freezing Rain,Snow Grains'
#  'Snow,Blowing Snow' 'Freezing Fog' 'Haze' 'Rain,Fog' 'Drizzle,Fog'
#  'Drizzle' 'Freezing Drizzle,Haze' 'Freezing Rain,Haze' 'Snow,Haze'
#  'Snow,Fog' 'Snow,Ice Pellets' 'Rain,Haze' 'Thunderstorms,Rain'
#  'Thunderstorms,Rain Showers' 'Thunderstorms,Heavy Rain Showers'
#  'Thunderstorms,Rain Showers,Fog' 'Thunderstorms' 'Thunderstorms,Rain,Fog'
#  'Thunderstorms,Moderate Rain Showers,Fog' 'Rain Showers,Fog'
#  'Rain Showers,Snow Showers' 'Snow Pellets' 'Rain,Snow,Fog'
#  'Moderate Rain,Fog' 'Freezing Rain,Ice Pellets,Fog'
#  'Drizzle,Ice Pellets,Fog' 'Drizzle,Snow' 'Rain,Ice Pellets'
#  'Drizzle,Snow,Fog' 'Rain,Snow Grains' 'Rain,Snow,Ice Pellets'
#  'Snow Showers,Fog' 'Moderate Snow,Blowing Snow']

# %%
# Cheking for outliers using Box plot
df[['Temp_C', 'Rel Hum_%', 'Wind Speed_km/h', 'Visibility_km', 'Press_kPa']].plot(kind='box')
plt.title('Distribution of Weather Parameters')
plt.show()

# %%
# # Correlation Matrix 1
# numeric_df = df.select_dtypes(include=[float, int])

# numeric_df.corr()

# %%
# teal_palette = ['#003D4D', '#005566', '#00697A', '#00868B', '#00A5A5',
#                 '#00C1C1', '#00CDCD', '#00E5E5']#'#00FFFF']
# corr = df1.corr()
# sns.heatmap(corr, annot=True, cmap=teal_palette, fmt='.2f')

# plt.title('Correlation Matrix', color='teal', fontweight='bold')

# plt.show()

# %%
# Top 15 weather conditions by Frequency
top_weather_conditions = df['Weather'].value_counts().head(15)

plt.figure(figsize=(12, 8))
top_weather_conditions.plot(kind='bar', color='teal')

plt.title('Top 15 Weather Conditions by Frequency')
plt.xlabel('Weather Condition')
plt.ylabel('Frequency')

# Show plot
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
colors = ['#003D4D','#00868B', '#00E5E5']

df.plot(x='Date/Time', y=['Temp_C', 'Dew Point Temp_C', 'Rel Hum_%'], kind='line', color = colors)
plt.title('Weather Parameters Over Time')
plt.xlabel('Date/Time')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
colors = ['#003D4D', '#00E5E5']

df.plot(x='Date/Time', y=['Wind Speed_km/h', 'Press_kPa'], kind='line', color = colors)
plt.title('Weather Parameters Over Time')
plt.xlabel('Date/Time')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
#Normal Temperatures mostly range between 0°C-5°C
plt.figure(figsize=(14, 6))

bin_range = (-25, 35)

sns.histplot(df['Temp_C'], bins=12, binrange=bin_range, color= 'teal', kde=False)

plt.xlabel('Temperature (°C)', fontsize=12)
plt.ylabel('Count', fontsize=12)

plt.title('Temperature Distribution', fontsize=16, color='teal')

plt.show()

# %%
#Temperature at dew point is mostly between 10°C-15°C
plt.figure(figsize=(14, 6))

bin_range = (-25, 25)

sns.histplot(df['Dew Point Temp_C'], bins=10, binrange=bin_range, color="teal", kde=False)

plt.xlabel('Temperature (°C)', fontsize=12)
plt.ylabel('Count', fontsize=12)

plt.title('Dew Point Temperature Distribution', fontsize=16, color='teal')

plt.show()

# %%
# Encoding Weather column
encoder = LabelEncoder()
df['Weather_encoded'] = encoder.fit_transform(df['Weather'])

# %%
df.head()
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather  Weather_encoded
# 0            8.0     101.24                   Fog                7
# 1            8.0     101.24                   Fog                7
# 2            4.0     101.26  Freezing Drizzle,Fog                9
# 3            4.0     101.27  Freezing Drizzle,Fog                9
# 4            4.8     101.23                   Fog                7

# %%
# Correlation
df1 = df[['Date/Time','Temp_C','Dew Point Temp_C','Rel Hum_%',
          'Wind Speed_km/h','Visibility_km','Press_kPa',
            'Weather_encoded']]
df1.corr()
# Out:
#                   Date/Time    Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Date/Time          1.000000  0.216369          0.297377   0.230190
# Temp_C             0.216369  1.000000          0.932714  -0.220182
# Dew Point Temp_C   0.297377  0.932714          1.000000   0.139494
# Rel Hum_%          0.230190 -0.220182          0.139494   1.000000
# Wind Speed_km/h   -0.024215 -0.061876         -0.095685  -0.092743
# Visibility_km     -0.024711  0.273455          0.050813  -0.633683
# Press_kPa          0.070127 -0.236389         -0.320616  -0.231424
# Weather_encoded   -0.011260  0.002244          0.007874   0.028313
#
#                   Wind Speed_km/h  Visibility_km  Press_kPa  Weather_encoded
# Date/Time               -0.024215      -0.024711   0.070127        -0.011260
# Temp_C                  -0.061876       0.273455  -0.236389         0.002244
# Dew Point Temp_C        -0.095685       0.050813  -0.320616         0.007874
# ...

# %%
# Correlation Matrix
teal_palette = ['#003D4D', '#005566', '#00697A', '#00868B', '#00A5A5',
                '#00C1C1', '#00CDCD', '#00E5E5']#'#00FFFF']
corr = df1.corr()
sns.heatmap(corr, annot=True, cmap=teal_palette, fmt='.2f')

plt.title('Correlation Matrix', color='teal', fontweight='bold')

plt.show()

# %%
# Normal Temperature and temperatures at dew point likely have a linear correlation
plt.figure(figsize=(10, 6))
plt.scatter(df['Temp_C'], df['Dew Point Temp_C'], color='teal')
plt.title('Scatter Plot of Temperature vs Temperature at dew point', color = 'teal')
plt.xlabel('Temperature')
plt.ylabel('Dew Point Temperature')
plt.grid(True)
plt.show()

# %%
# Weather conditions are most likely correlated with pressure followed by wind speed then Visibility.

teal_palette = ['#008080', '#00CCCC', '#00CED1', '#00FFFF', '#00CED1']

# Features selection (5 best correlation)
corr = df1.corr()['Weather_encoded'].abs().sort_values(ascending=False)

k = 5
selected_features = corr[1:k+1].index.tolist()

# Create a pie plot
explode = [0.1,0,0,0,0]
plt.figure(figsize=(8, 8))
plt.pie(corr[1:k+1], labels=selected_features, autopct='%1.1f%%',
        explode = explode,shadow = True, startangle=90,
        colors=teal_palette, wedgeprops = {'edgecolor' : 'black'})
plt.title('Top 5 Correlated Features with Weather',c ='teal')
# Out:
# Text(0.5, 1.0, 'Top 5 Correlated Features with Weather')

# %%
teal_palette = ['#008080', '#00868B', '#008E8E', '#009696', '#009B9B', '#00A5A5',
                '#00AAAA']

# Features selection (15 best correlation)
corr = df2.corr()['Weather_encoded'].abs().sort_values(ascending=False)

k = 15
top_features = corr[1:k+1]

# Reverse the order
top_features = top_features[::-1]

# Create a horizontal bar chart
plt.figure(figsize=(10, 8))
plt.barh(top_features.index, top_features, color=teal_palette)
plt.xlabel('Absolute Correlation')
plt.title('Correlations with Weather_encoded',c='teal')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()
